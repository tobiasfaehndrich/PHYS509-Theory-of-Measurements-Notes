# %% [markdown]
# ### Problem 1
# File `exp1000.txt` contains a simulated list of decay times from an experiment.
#
# (a) Perform a least squares fit to this distribution for the lifetime $\tau$, to find the best estimate and also its uncertainty. Plot your fit results on your histogram of the data.
#
# (b) Plot a scan of the $\chi^2$ about the minimum over a range that shows at least the $\pm 3\sigma$ region with lines indicating the 1, 2, and 3$\sigma$ levels on the $\chi^2$ plot. Make a table with the symmetric and asymmetric confidence intervals for 1, 2, and 3$\sigma$ limits.

# %%
from matplotlib import pyplot as plt
import numpy as np
import scienceplots

plt.style.use(['science', 'notebook'])

data = np.loadtxt('exp1000.txt', skiprows = 1)


plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('Decay Time')
plt.ylabel('Frequency')
plt.show()


# part (a)
